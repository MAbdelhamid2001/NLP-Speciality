# %%
import numpy as np
import pandas as pd

# %%
data=r'quora_questions.csv'
df=pd.read_csv(data)

# %%
df
# Out:
#                                                  Question
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404284  How many keywords are there in the Racket prog...
# 404285          Do you believe there is life after death?
# 404286                                  What is one coin?
# 404287  What is the approx annual cost of living while...
# 404288              What is like to have sex with cousin?
#
# [404289 rows x 1 columns]

# %% [markdown]
# ## Preprocessing

# %%
import re

df['prep']=df['Question'].apply(lambda x:re.sub("[^A-Za-z]+",' ',x))

df['prep']=df['prep'].apply(lambda x:re.sub(" \w ",' ',x))

df['prep']=df['prep'].apply(lambda x:re.sub(" \w\w ",' ',x))

df['prep']=df['prep'].apply(lambda x:x.strip())
df['prep']=df['prep'].apply(lambda x:x.lower())

# %% [markdown]
# ## Feature Extraction

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
' '.join(['a','b','c'])
# Out:
# 'a b c'

# %%
def lemmatizer(text):
    x=[word.lemma_ for word in nlp(text)]
    return ' '.join(x)

# %%
df['Question'].iloc[0]
lemmatizer(df['Question'].iloc[0])
# Out:
# 'what be the step by step guide to invest in share market in india ?'

# %%
df['Question']=df['Question'].apply(lemmatizer)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf=TfidfVectorizer(max_df=0.95,min_df=2,stop_words='english')

dtm=tfidf.fit_transform(df['prep'])

# pd.DataFrame(data=dtm.toarray(),columns=tfidf.get_feature_names_out())

# %%
dtm
# Out:
# <404289x36620 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1937429 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## NMF

# %%
from sklearn.decomposition import NMF

# %%
nmf=NMF(n_components=20,random_state=42)

# %%
nmf.fit(dtm)
# Out:
# NMF(n_components=20, random_state=42)

# %%
nmf.components_.shape
# Out:
# (20, 36620)

# %%
for index,comp in enumerate(nmf.components_):
    print(f"Topic:{index}")
    top_words=comp.argsort()[-15:]
    print(tfidf.get_feature_names_out()[top_words])
    print('\n')
# Out:
# Topic:0
# ['read' 'place' 'smartphone' 'mobile' 'visit' 'places' 'ways' 'movie'
#  'buy' 'phone' 'books' 'book' 'laptop' 'movies' 'best']
#
#
# Topic:1
# ['grads' 'recruit' 'looking' 'differ' 'sex' 'use' 'exist' 'really'
#  'compare' 'cost' 'long' 'feel' 'work' 'mean' 'does']
#
#
# Topic:2
# ['investment' 'help' 'free' 'home' 'easy' 'internet' 'banning' 'rupee'
#  'youtube' 'notes' 'black' 'ways' 'earn' 'online' 'money']
#
#
# Topic:3
# ['add' 'answered' 'needing' 'post' 'easily' 'improvement' 'delete' 'asked'
#  'google' 'answers' 'answer' 'ask' 'question' 'questions' 'quora']
#
#
# Topic:4
# ['balance' 'earth' 'day' 'death' 'changed' 'want' 'live' 'change' 'moment'
#  'real' 'important' 'thing' 'meaning' 'purpose' 'life']
#
#
# Topic:5
# ['america' 'happen' 'presidency' 'think' 'presidential' 'vote' 'better'
#  'election' 'did' 'win' 'hillary' 'president' 'clinton' 'donald' 'trump']
#
#
# Topic:6
# ['english' 'beginner' 'beginners' 'computer' 'hacking' 'book' 'want'
#  'python' 'languages' 'java' 'start' 'learning' 'language' 'programming'
#  'learn']
#
#
# Topic:7
# ['earth' 'blowing' 'stop' 'easily' 'mind' 'use' 'google' 'flat'
#  'questions' 'hate' 'believe' 'ask' 'don' 'think' 'people']
#
#
# Topic:8
# ['minister' 'ban' 'country' 'banning' 'olympics' 'job' 'available'
#  'indian' 'rupee' 'think' 'war' 'spotify' 'notes' 'pakistan' 'india']
#
#
# Topic:9
# ['indian' 'companies' 'don' 'guy' 'men' 'culture' 'women' 'girls' 'work'
#  'live' 'girl' 'look' 'sex' 'feel' 'like']
#
#
# Topic:10
# ['solar' 'panel' 'provider' 'movies' 'business' 'score' 'songs' 'read'
#  'job' 'work' 'engineering' 'ways' 'bad' 'books' 'good']
#
#
# Topic:11
# ['help' 'days' 'healthy' 'exercise' 'reduce' 'month' 'quickly' 'loss'
#  'pounds' 'fast' 'fat' 'ways' 'gain' 'lose' 'weight']
#
#
# Topic:12
# ['blowing' 'mind' 'likes' 'resolutions' 'girl' 'resolution' 'old' 'don'
#  'year' 'employees' 'going' 'day' 'things' 'new' 'know']
#
#
# Topic:13
# ['aspects' 'fluent' 'skill' 'spoken' 'ways' 'language' 'fluently'
#  'communication' 'speak' 'pronunciation' 'speaking' 'writing' 'skills'
#  'improve' 'english']
#
#
# Topic:14
# ['real' 'feel' 'did' 'long' 'spend' 'person' 'machine' 'favorite' 'job'
#  'home' 'movies' 'sex' 'possible' 'travel' 'time']
#
#
# Topic:15
# ['marriage' 'doesn' 'did' 'girlfriend' 'feel' 'tell' 'forget' 'really'
#  'friend' 'true' 'know' 'person' 'girl' 'fall' 'love']
#
#
# Topic:16
# ['phone' 'mechanical' 'scripting' 'java' 'iphone' 'account' 'better' 'job'
#  'use' 'data' 'software' 'science' 'computer' 'engineering' 'difference']
#
#
# Topic:17
# ['easy' 'height' 'quickest' 'facebook' 'prepare' 'painless' 'instagram'
#  'account' 'increase' 'best' 'commit' 'fastest' 'suicide' 'easiest' 'way']
#
#
# Topic:18
# ['million' 'easy' 'great' 'video' 'old' 'android' 'happy' 'app' 'better'
#  'youtube' 'month' 'year' 'friends' 'money' 'make']
#
#
# Topic:19
# ['coming' 'win' 'countries' 'place' 'learning' 'pakistan' 'happen' 'end'
#  'country' 'iii' 'business' 'did' 'start' 'war' 'world']

# %%
topic_results=nmf.fit_transform(dtm)

# %%
topic_results.shape
# Out:
# (404289, 20)

# %%
df['topic']=topic_results.argmax(axis=1)

# %%
df
# Out:
#                                                  Question  \
# 0       What is the step by step guide to invest in sh...
# 1       What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2       How can I increase the speed of my internet co...
# 3       Why am I mentally very lonely? How can I solve...
# 4       Which one dissolve in water quikly sugar, salt...
# ...                                                   ...
# 404284  How many keywords are there in the Racket prog...
# 404285          Do you believe there is life after death?
# 404286                                  What is one coin?
# 404287  What is the approx annual cost of living while...
# 404288              What is like to have sex with cousin?
#
#                                                      prep  topic
# 0       what the step step guide invest share market i...      8
# 1                what the story kohinoor koh noor diamond     15
# 2       how can increase the speed my internet connect...     17
# 3                  why mentally very lonely how can solve      9
# 4       which one dissolve water quikly sugar salt met...      1
# ...                                                   ...    ...
# 404284  how many keywords are there the racket program...      6
# 404285              do you believe there life after death      4
# 404286                                      what one coin      8
# 404287  what the approx annual cost living while study...      9
# 404288                     what like have sex with cousin      9
#
# [404289 rows x 3 columns]
